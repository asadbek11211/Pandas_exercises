# %% [markdown]
# <a href="https://colab.research.google.com/github/asadbek11211/Pandas_exercises/blob/main/pivot_table(irarxik_indekslash).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dunyo shaharlarining havo va suv sifati ma'lumotlari ustida amallar bajarish

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git # Githubdagi reponi nusxalab oladi
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
columns=['City','Region','Country','AirQuality','WaterPolution']
df.columns = columns

# %%
df.head()
# Out:
#                City                   Region                      Country  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#    AirQuality  WaterPolution
# 0   46.816038      49.504950
# 1   66.129032      49.107143
# 2   60.514019      43.000000
# 3   62.364130      28.612717
# 4   36.621622      61.299435

# %% [markdown]
# DF elementlaridaggi 2tirnoqlarni olib tashlaymiz

# %%
df['Region'] = df.Region.map(lambda n: n.replace('"',''))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPolution
# 0      46.816038      49.504950
# ...

# %%
df['Country'] = df.Country.map(lambda n: n.replace('"',''))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPolution
# 0      46.816038      49.504950
# ...

# %%
df.at[4,'Region']
# Out:
# ' California'

# %%
df.at[9,'Country']
# Out:
# ' United Kingdom'

# %% [markdown]
# Etibor bergan bo'lsangiz Country ustin elementlarining old qismida bosh joy qolib ketgan uni olib tashlaymiz

# %%
df['Country'] = df.Country.map(lambda n: n.strip())

# %%
df.at[9,'Country']
# Out:
# 'United Kingdom'

# %%
df[df.Country == 'Russia']
# Out:
#                   City                  Region Country  AirQuality  \
# 50              Moscow                          Russia   41.475265
# 51    Saint Petersburg                          Russia   43.103448
# 57              Abakan   Republic of Khakassia  Russia    0.000000
# 58         Novosibirsk      Novosibirsk Oblast  Russia   36.486486
# 59       Yekaterinburg       Sverdlovsk Oblast  Russia   27.906977
# ...                ...                     ...     ...         ...
# 1946    Sergiyev Posad           Moscow Oblast  Russia   75.000000
# 1952         Serpukhov           Moscow Oblast  Russia    0.000000
# 1962       Stary Oskol         Belgorod Oblast  Russia    0.000000
# 1968            Khimki           Moscow Oblast  Russia   33.333333
# 3842         Innopolis   Republic of Tatarstan  Russia  100.000000
#
#       WaterPolution
# 50        49.725275
# 51        54.881657
# 57        75.000000
# 58        54.054054
# 59        58.333333
# ...             ...
# ...

# %% [markdown]
# # pivot_table orqali irarxik indekslash

# %%
df1 = df.pivot_table(df, index=['Country','City'])
df1
# Out:
#                       AirQuality  WaterPolution
# Country     City
# Afghanistan Andkhoy    50.000000      50.000000
#             Farah     100.000000       0.000000
#             Herat      43.750000      31.250000
#             Kabul      18.421053      81.060606
#             Kandahar    0.000000      75.000000
# ...                          ...            ...
# Zambia      Mansa      75.000000      25.000000
# Zimbabwe    Bindura    50.000000      75.000000
#             Bulawayo   67.857143      71.428571
#             Harare     38.461538      87.500000
#             Masvingo   25.000000      62.500000
#
# [3895 rows x 2 columns]

# %%
df1.loc[['Germany','Russia']]
# Out:
#                            AirQuality  WaterPolution
# Country City
# Germany Aachen              70.454545      17.857143
#         Aalen               87.500000      50.000000
#         Abensberg          100.000000      50.000000
#         Amberg             100.000000      50.000000
#         Annaberg-Buchholz   87.500000      50.000000
# ...                               ...            ...
# Russia  Yakutsk             58.333333      87.500000
#         Yaroslavl           16.666667      58.333333
#         Yekaterinburg       27.906977      58.333333
#         Yoshkar-Ola        100.000000      50.000000
#         Yuzhno-Sakhalinsk    8.333333      75.000000
#
# [210 rows x 2 columns]

# %%
n = df[df.Country == 'Russia']

n.City.unique()
# Out:
# array(['Moscow', 'Saint Petersburg', 'Abakan', 'Novosibirsk',
#        'Yekaterinburg', 'Samara', 'Omsk', 'Kazan', 'Chelyabinsk', 'Ufa',
#        'Volgograd', 'Perm', 'Krasnoyarsk', 'Vladivostok', 'Tomsk',
#        'Tolyatti', 'Murmansk', 'Kaliningrad', 'Arkhangelsk',
#        'Petrozavodsk', 'Vologda', 'Cherepovets', 'Pskov',
#        'Veliky Novgorod', 'Tver', 'Smolensk', 'Yaroslavl', 'Ivanovo',
#        'Vladimir', 'Ryazan', 'Tula', 'Kursk', 'Belgorod', 'Voronezh',
#        'Lipetsk', 'Tambov', 'Krasnodar', 'Astrakhan', 'Khabarovsk',
#        'Makhachkala', 'Stavropol', 'Vladikavkaz', 'Saratov', 'Orenburg',
#        'Saransk', 'Kirov', 'Izhevsk', 'Yoshkar-Ola', 'Cheboksary',
#        'Penza', 'Ulyanovsk', 'Tyumen', 'Kemerovo', 'Irkutsk', 'Yakutsk',
#        'Blagoveshchensk', 'Yuzhno-Sakhalinsk', 'Novorossiysk',
#        'Simferopol', 'Sochi', 'Kurchatov', 'Dzerzhinsk', 'Novokuznetsk',
#        'Magnitogorsk', 'Nizhny Tagil', 'Volzhsky', 'Bakal', 'Balashikha',
# ...

# %%
df[df.City == 'Novosibirsk']
# Out:
#            City               Region Country  AirQuality  WaterPolution
# 58  Novosibirsk   Novosibirsk Oblast  Russia   36.486486      54.054054

# %%
df1.loc[['Uzbekistan', 'Germany', 'Tajikistan']]
# Out:
#                       AirQuality  WaterPolution
# Country    City
# Uzbekistan Tashkent    56.451613      49.166667
# Germany    Aachen      70.454545      17.857143
#            Aalen       87.500000      50.000000
#            Abensberg  100.000000      50.000000
#            Amberg     100.000000      50.000000
# ...                          ...            ...
#            Wolfsburg   96.875000       0.000000
#            Worms       60.000000     100.000000
#            Wuppertal   90.000000       0.000000
#            Zwickau     75.000000      50.000000
# Tajikistan Dushanbe    41.666667      61.111111
#
# [126 rows x 2 columns]

# %% [markdown]
# # Ustunlarni irarxik ko'rinishga keltirish

# %%
df1
# Out:
#                       AirQuality  WaterPolution
# Country     City
# Afghanistan Andkhoy    50.000000      50.000000
#             Farah     100.000000       0.000000
#             Herat      43.750000      31.250000
#             Kabul      18.421053      81.060606
#             Kandahar    0.000000      75.000000
# ...                          ...            ...
# Zambia      Mansa      75.000000      25.000000
# Zimbabwe    Bindura    50.000000      75.000000
#             Bulawayo   67.857143      71.428571
#             Harare     38.461538      87.500000
#             Masvingo   25.000000      62.500000
#
# [3895 rows x 2 columns]

# %% [markdown]
# Keling df1 ga yana cator kiritamiz Suvning ifloslanishi va Havoning tozaligi haqidagi collumns larni qo'shamiz

# %%
df1['AirPolution'] = 100 - df1.AirQuality
df1['WaterQuality'] = 100 - df1.WaterPolution

# %%
df1
# Out:
#                       AirQuality  WaterPolution  AirPolution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000      50.000000    50.000000     50.000000
#             Farah     100.000000       0.000000     0.000000    100.000000
#             Herat      43.750000      31.250000    56.250000     68.750000
#             Kabul      18.421053      81.060606    81.578947     18.939394
#             Kandahar    0.000000      75.000000   100.000000     25.000000
# ...                          ...            ...          ...           ...
# Zambia      Mansa      75.000000      25.000000    25.000000     75.000000
# Zimbabwe    Bindura    50.000000      75.000000    50.000000     25.000000
#             Bulawayo   67.857143      71.428571    32.142857     28.571429
#             Harare     38.461538      87.500000    61.538462     12.500000
#             Masvingo   25.000000      62.500000    75.000000     37.500000
#
# [3895 rows x 4 columns]

# %% [markdown]
# Endi collumns boyicha ierarxik indekslaymiz

# %%
df2 = pd.DataFrame(df1.values, index=df1.index, columns=[['Air','Air','Water','Water'],['AirQuality','AirPolution','WaterQuality','WaterPolution']])
df2
# Out:
#                              Air                    Water
#                       AirQuality AirPolution WaterQuality WaterPolution
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000    50.000000     50.000000
#             Farah     100.000000    0.000000     0.000000    100.000000
#             Herat      43.750000   31.250000    56.250000     68.750000
#             Kabul      18.421053   81.060606    81.578947     18.939394
#             Kandahar    0.000000   75.000000   100.000000     25.000000
# ...                          ...         ...          ...           ...
# Zambia      Mansa      75.000000   25.000000    25.000000     75.000000
# Zimbabwe    Bindura    50.000000   75.000000    50.000000     25.000000
#             Bulawayo   67.857143   71.428571    32.142857     28.571429
#             Harare     38.461538   87.500000    61.538462     12.500000
#             Masvingo   25.000000   62.500000    75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df2['Air']
# Out:
# Info                  AirQuality  AirPolution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000
#             Farah     100.000000     0.000000
#             Herat      43.750000    31.250000
#             Kabul      18.421053    81.060606
#             Kandahar    0.000000    75.000000
# ...                          ...          ...
# Zambia      Mansa      75.000000    25.000000
# Zimbabwe    Bindura    50.000000    75.000000
#             Bulawayo   67.857143    71.428571
#             Harare     38.461538    87.500000
#             Masvingo   25.000000    62.500000
#
# [3895 rows x 2 columns]

# %%
df2.columns.names = ['Object','Info']
df2
# Out:
# Object                       Air                    Water
# Info                  AirQuality AirPolution WaterQuality WaterPolution
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000    50.000000     50.000000
#             Farah     100.000000    0.000000     0.000000    100.000000
#             Herat      43.750000   31.250000    56.250000     68.750000
#             Kabul      18.421053   81.060606    81.578947     18.939394
#             Kandahar    0.000000   75.000000   100.000000     25.000000
# ...                          ...         ...          ...           ...
# Zambia      Mansa      75.000000   25.000000    25.000000     75.000000
# Zimbabwe    Bindura    50.000000   75.000000    50.000000     25.000000
#             Bulawayo   67.857143   71.428571    32.142857     28.571429
#             Harare     38.461538   87.500000    61.538462     12.500000
#             Masvingo   25.000000   62.500000    75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df2.to_csv("World_country_(Air,Water)Quality.csv")
