# %% [markdown]
# <a href="https://colab.research.google.com/github/asadbek11211/Pandas_exsamples/blob/main/Read_html_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1507486406.jpg](data:image/jpeg;base64,...)
# Web brauzerdan malumotlarni jadval ko'rinishida olamiz.
# misol uchun (Mike Tyson)

# %%
import numpy as np
import pandas as pd

# %%
mike = pd.read_html("https://en.wikipedia.org/wiki/Mike_Tyson")

# %% [markdown]
# mike nomli list o'zida bir qancha DataFrame larni oldi

# %%
len(mike)
# Out:
# 19

# %%
mike[0].head()
# Out:
#       Mike Tyson                                       Mike Tyson.1 Unnamed: 2
# 0  Tyson in 2019                                      Tyson in 2019        NaN
# 1           Born  Michael Gerard Tyson (age 56)Brooklyn, New Yor...        NaN
# 2        Spouses  .mw-parser-output .plainlist ol,.mw-parser-out...        NaN
# 3       Children                                               7[a]        NaN
# 4  Boxing career                                      Boxing career        NaN

# %%
mike[1].head()
# Out:
#                           0                         1  \
# 0                       NaN                       NaN
# 1      Men's amateur boxing      Men's amateur boxing
# 2  National Junior Olympics  National Junior Olympics
# 3                       NaN       1981 North Carolina
# 4                       NaN            1982 Tennessee
#
#                           2
# 0                       NaN
# 1      Men's amateur boxing
# 2  National Junior Olympics
# 3               Heavyweight
# 4               Heavyweight

# %%
mike[2].head()
# Out:
#              58 fights  50 wins  6 losses
# 0          By knockout       44         5
# 1          By decision        5         0
# 2  By disqualification        1         1
# 3          No contests        2         2

# %%
mike[3].head()
# Out:
#    No. Result    Record          Opponent Type   Round, time          Date  \
# 0   58   Loss  50–6 (2)     Kevin McBride  RTD  6 (10), 3:00  Jun 11, 2005
# 1   57   Loss  50–5 (2)    Danny Williams   KO  4 (10), 2:51  Jul 30, 2004
# 2   56    Win  50–4 (2)  Clifford Etienne   KO  1 (10), 0:49  Feb 22, 2003
# 3   55   Loss  49–4 (2)      Lennox Lewis   KO  8 (12), 2:25   Jun 8, 2002
# 4   54    Win  49–3 (2)     Brian Nielsen  RTD  6 (10), 3:00  Oct 13, 2001
#
#                   Age                                  Location  \
# 0  38 years, 346 days        MCI Center, Washington, D.C., U.S.
# 1   38 years, 30 days  Freedom Hall, Louisville, Kentucky, U.S.
# 2  36 years, 237 days     The Pyramid, Memphis, Tennessee, U.S.
# 3  35 years, 343 days     The Pyramid, Memphis, Tennessee, U.S.
# 4  35 years, 115 days       Parken Stadium, Copenhagen, Denmark
#
#                                                Notes
# 0                                                NaN
# ...

# %%
mike[4].head()
# Out:
#      4 fights  0 wins  0 losses
# 0       Draws       1         1
# 1  Non-scored       3         3

# %%
mike[5].head()
# Out:
#    No. Result     Record       Opponent Type  Round, time          Date  \
# 0    4   Draw  0–0–1 (3)  Roy Jones Jr.   SD            8  Nov 28, 2020
# 1    3      —    0–0 (3)  Corey Sanders    —            4  Oct 20, 2006
# 2    2      —    0–0 (2)   James Tillis    —            4  Nov 12, 1987
# 3    1      —    0–0 (1)  Anthony Davis    —            1   Jul 4, 1986
#
#                                             Location              Notes
# 0      Staples Center, Los Angeles, California, U.S.  Scored by the WBC
# 1           Chevrolet Centre, Youngstown, Ohio, U.S.    Non-scored bout
# 2  DePaul University Alumni Hall, Chicago, Illino...    Non-scored bout
# 3  Liberty State Park, Jersey City, New Jersey, U.S.    Non-scored bout

# %%
mike[6].head()
# Out:
#    No.             Date                 Fight                  Billing  \
# 0  1.0    June 27, 1988      Tyson vs. Spinks         Once and For All
# 1  2.0   March 18, 1991     Tyson vs. Ruddock    The Fight of the Year
# 2  3.0    June 28, 1991  Tyson vs. Ruddock II              The Rematch
# 3  4.0  August 19, 1995    Tyson vs. McNeeley                He's Back
# 4  5.0   March 16, 1996    Tyson vs. Bruno II  The Championship Part I
#
#              Buys               Network
# 0    700,000[260]           King Vision
# 1    960,000[261]           King Vision
# 2  1,250,000[262]           King Vision
# 3  1,600,000[263]  Showtime/King Vision
# 4  1,400,000[263]  Showtime/King Vision

# %%
mike[7].head()
# Out:
#                Date                                Fight         Network  \
# 0    March 16, 1996        Frank Bruno vs. Mike Tyson II  Sky Box Office
# 1     June 28, 1997  Evander Holyfield vs. Mike Tyson II  Sky Box Office
# 2  January 29, 2000        Mike Tyson vs. Julius Francis  Sky Box Office
# 3      June 8, 2002          Lennox Lewis vs. Mike Tyson  Sky Box Office
# 4               NaN                          Total sales             NaN
#
#       Buys Source(s)
# 0   600000     [269]
# 1   550000     [270]
# 2   500000     [270]
# 3   750000     [271]
# 4  2400000       NaN

# %%
mike[8].head()
# Out:
#             Date                                Fight          Buys  \
# 0  June 27, 1988        Mike Tyson vs. Michael Spinks  800,000[272]
# 1  June 28, 1997  Evander Holyfield vs. Mike Tyson II  120,000[273]
# 2            NaN                          Total sales        920000
#
#             Revenue Revenue (inflation)
# 0  $32,000,000[272]         $73,320,000
# 1   $9,000,000[274]         $15,190,000
# 2       $41,000,000         $79,930,000

# %%
mike[9].head()
# Out:
#              Date             Event        Venue                     Location  \
# 0  March 29, 1998  WrestleMania XIV  FleetCenter  Boston, Massachusetts, U.S.
#
#      Buys    Ref
# 0  730000  [275]

# %%
mike[10]
# Out:
#            Date              Event                         Venue  \
# 0  May 23, 2020  Double or Nothing  Daily's PlaceTIAA Bank Field
#
#                 Location             Buys         Ref
# 0  Jacksonville, Florida  115,000–120,000  [276][277]

# %%
mike[11].head()
# Out:
#           Sporting positions  \
# 0      Amateur boxing titles
# 1   Previous:Olian Alexander
# 2        World boxing titles
# 3  Preceded byTrevor Berbick
# 4     Preceded byJames Smith
#
#                                 Sporting positions.1  \
# 0                              Amateur boxing titles
# 1        U.S. Golden Glovesheavyweight champion 1984
# 2                                World boxing titles
# 3  WBC heavyweight champion November 22, 1986 – F...
# 4  WBA heavyweight champion March 7, 1987 – Febru...
#
#          Sporting positions.2             Unnamed: 3             Unnamed: 4
# 0       Amateur boxing titles  Amateur boxing titles  Amateur boxing titles
# 1             Next:Jerry Goff                    NaN                    NaN
# 2         World boxing titles    World boxing titles    World boxing titles
# 3  Succeeded byBuster Douglas                    NaN                    NaN
# 4  Succeeded byBuster Douglas                    NaN                    NaN

# %%
mike[12].head()
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteMike Tyson  \
# 0                                             Fights
# 1                                              Films
# 2                                         Television
# ...

# %%
mike[13].head()
# Out:
#                             0  \
# 0    initial (D'Amato stable)
# 1  mid-career (King's stable)
#
#                                                    1
# 0  mentor: Cus D'Amato; co-managers: Jimmy Jacobs...
# 1  manager: Don King; trainer: Richie Giachetti; ...

# %%
mike[15].head()
# Out:
#   vteBBC Sports Personality World Sport Star of the Year  \
# 0  1960: Herb Elliott 1961: Valeriy Brumel 1962: ...
#
#   vteBBC Sports Personality World Sport Star of the Year.1
# 0  1960: Herb Elliott 1961: Valeriy Brumel 1962: ...

# %%
mike[16].head()
# Out:
#                          vteSugar Ray Robinson Award  \
# 0  1938: Dempsey 1939: Conn 1940: Armstrong 1941:...
#
#                        vteSugar Ray Robinson Award.1
# 0  1938: Dempsey 1939: Conn 1940: Armstrong 1941:...

# %%
mike[17].head()
# Out:
#                 vteWWE Hall of Fame - Celebrity Wing  \
# 0  2004: Pete Rose 2006: William Perry 2010: Bob ...
#
#               vteWWE Hall of Fame - Celebrity Wing.1
# 0  2004: Pete Rose 2006: William Perry 2010: Bob ...

# %%
mike[18].head()
# Out:
#     Authority control                                Authority control.1
# 0             General                             ISNI 1 VIAF 1 WorldCat
# 1  National libraries  Norway Spain France (data) Catalonia Germany I...
# 2               Other  FAST MusicBrainz artist National Archives (US)...
