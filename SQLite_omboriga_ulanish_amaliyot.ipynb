# %% [markdown]
# <a href="https://colab.research.google.com/github/asadbek11211/Pandas_exsamples/blob/main/SQLite_omboriga_ulanish_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQLite ma'lumotlar ombori bilan ishlash

# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
! wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2023-02-14 16:39:01--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 151.139.128.10
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|151.139.128.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.008s
#
# 2023-02-14 16:39:01 (37.6 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db = sql.connect("chinook.db")
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT (*) FROM customers")
cursor.fetchone()
# Out:
# (59,)

# %%
cursor.execute("PRAGMA table_info(customers);")
cursor.fetchall()
# Out:
# [(0, 'CustomerId', 'INTEGER', 1, None, 1),
#  (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0),
#  (2, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Company', 'NVARCHAR(80)', 0, None, 0),
#  (4, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (5, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (6, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (7, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (9, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (10, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (11, 'Email', 'NVARCHAR(60)', 1, None, 0),
#  (12, 'SupportRepId', 'INTEGER', 0, None, 0)]

# %%
cursor.execute("SELECT COUNT (*) FROM employees")
cursor.fetchone()
# Out:
# (8,)

# %%
from sqlite3.dbapi2 import Cursor
cursor.execute("SELECT * FROM customers")
cus = cursor.fetchall()

# %%
df = pd.read_sql("SELECT * FROM customers", db, index_col='CustomerId')

# %%
df
# Out:
#             FirstName      LastName  \
# CustomerId
# 1                Luís     Gonçalves
# 2              Leonie        Köhler
# 3            François      Tremblay
# 4               Bjørn        Hansen
# 5           František   Wichterlová
# 6              Helena          Holý
# 7              Astrid        Gruber
# 8                Daan       Peeters
# 9                Kara       Nielsen
# 10            Eduardo       Martins
# 11          Alexandre         Rocha
# 12            Roberto       Almeida
# 13           Fernanda         Ramos
# 14               Mark       Philips
# 15           Jennifer      Peterson
# 16              Frank        Harris
# 17               Jack         Smith
# 18           Michelle        Brooks
# 19                Tim         Goyer
# 20                Dan        Miller
# 21              Kathy         Chase
# 22            Heather       Leacock
# 23               John        Gordon
# 24              Frank       Ralston
# ...

# %%
pd.read_sql("SELECT * FROM customers LIMIT 20", db, index_col='CustomerId')
# Out:
#             FirstName     LastName  \
# CustomerId
# 1                Luís    Gonçalves
# 2              Leonie       Köhler
# 3            François     Tremblay
# 4               Bjørn       Hansen
# 5           František  Wichterlová
# 6              Helena         Holý
# 7              Astrid       Gruber
# 8                Daan      Peeters
# 9                Kara      Nielsen
# 10            Eduardo      Martins
# 11          Alexandre        Rocha
# 12            Roberto      Almeida
# 13           Fernanda        Ramos
# 14               Mark      Philips
# 15           Jennifer     Peterson
# 16              Frank       Harris
# 17               Jack        Smith
# 18           Michelle       Brooks
# 19                Tim        Goyer
# 20                Dan       Miller
#
#                                                      Company  \
# CustomerId
# 1           Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                       None
# ...

# %%
df = pd.read_sql("SELECT * FROM artists", db, index_col='ArtistId')

# %%
df
# Out:
#                                                        Name
# ArtistId
# 1                                                     AC/DC
# 2                                                    Accept
# 3                                                 Aerosmith
# 4                                         Alanis Morissette
# 5                                           Alice In Chains
# ...                                                     ...
# 271        Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 272                                  Emerson String Quartet
# 273       C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 274                                           Nash Ensemble
# 275                                   Philip Glass Ensemble
#
# [275 rows x 1 columns]

# %%
df = pd.read_sql("SELECT * FROM customers LIMIT 15 ", db, index_col='CustomerId')

# %%
df.head()
# Out:
#             FirstName     LastName  \
# CustomerId
# 1                Luís    Gonçalves
# 2              Leonie       Köhler
# 3            François     Tremblay
# 4               Bjørn       Hansen
# 5           František  Wichterlová
#
#                                                      Company  \
# CustomerId
# 1           Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                       None
# 3                                                       None
# 4                                                       None
# 5                                           JetBrains s.r.o.
#
#                                     Address                 City State  \
# CustomerId
# 1           Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP
# 2                   Theodor-Heuss-Straße 34            Stuttgart  None
# 3                         1498 rue Bélanger             Montréal    QC
# ...

# %%
df = pd.read_sql("SELECT LastName, Address, Country  FROM customers", db)

# %%
df
# Out:
#         LastName                                   Address         Country
# 0      Gonçalves           Av. Brigadeiro Faria Lima, 2170          Brazil
# 1         Köhler                   Theodor-Heuss-Straße 34         Germany
# 2       Tremblay                         1498 rue Bélanger          Canada
# 3         Hansen                          Ullevålsveien 14          Norway
# 4    Wichterlová                             Klanova 9/506  Czech Republic
# 5           Holý                             Rilská 3174/6  Czech Republic
# 6         Gruber      Rotenturmstraße 4, 1010 Innere Stadt         Austria
# 7        Peeters                           Grétrystraat 63         Belgium
# 8        Nielsen                       Sønder Boulevard 51         Denmark
# 9        Martins                 Rua Dr. Falcão Filho, 155          Brazil
# 10         Rocha                        Av. Paulista, 2022          Brazil
# ...
