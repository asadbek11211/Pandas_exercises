# %% [markdown]
# <a href="https://colab.research.google.com/github/asadbek11211/Pandas_exercises/blob/main/Russian_university_ranking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Russian university ranking

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://www.scimagoir.com/rankings.php?sector=Higher+educ.&country=RUS => sahifadagi jadvallarni read_html() yordamida list1 ga saqlaymiz

# %%
list1 = pd.read_html("https://www.scimagoir.com/rankings.php?sector=Higher+educ.&country=RUS")

# %%
len(list1)
# Out:
# 1

# %%
df = list1[0]
df
# Out:
#      Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0           NaN    1 (335)                  Lomonosov Moscow State University
# 1           NaN    2 (498)                  Saint Petersburg State University
# 2           NaN    3 (510)                     State University of Management
# 3           NaN    4 (553)      State University - Higher School of Economics
# 4           NaN    5 (560)  Peter the Great St Petersburg Polytechnic Univ...
# ..          ...        ...                                                ...
# 160         NaN   96 (786)                            Tambov State University
# 161         NaN   96 (786)                          Dagestan State University
# 162         NaN   97 (789)                         Yaroslavl State University
# 163         NaN   98 (790)               Kabardino-Balkarian State University
# 164         NaN   99 (802)                              Tver State University
#
# ...

# %% [markdown]
# Keling biroz o'zgartirish kiritamiz jadvalimizga

# %%
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 4  Bestquartile
# count         0.0         0.0           0.0
# mean          NaN         NaN           NaN
# std           NaN         NaN           NaN
# min           NaN         NaN           NaN
# 25%           NaN         NaN           NaN
# 50%           NaN         NaN           NaN
# 75%           NaN         NaN           NaN
# max           NaN         NaN           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    0 non-null      float64
#  1   Unnamed: 1    165 non-null    object
#  2   Unnamed: 2    165 non-null    object
#  3   Unnamed: 3    165 non-null    object
#  4   Unnamed: 4    0 non-null      float64
#  5   Bestquartile  0 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 7.9+ KB

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 4', 'Bestquartile'], inplace=True)

# %%
df
# Out:
#     Unnamed: 1                                         Unnamed: 2 Unnamed: 3
# 0      1 (335)                  Lomonosov Moscow State University        RUS
# 1      2 (498)                  Saint Petersburg State University        RUS
# 2      3 (510)                     State University of Management        RUS
# 3      4 (553)      State University - Higher School of Economics        RUS
# 4      5 (560)  Peter the Great St Petersburg Polytechnic Univ...        RUS
# ..         ...                                                ...        ...
# 160   96 (786)                            Tambov State University        RUS
# 161   96 (786)                          Dagestan State University        RUS
# 162   97 (789)                         Yaroslavl State University        RUS
# 163   98 (790)               Kabardino-Balkarian State University        RUS
# 164   99 (802)                              Tver State University        RUS
#
# [165 rows x 3 columns]

# %% [markdown]
# # Keling endi calumns larni nomini o'zgartiramiz

# %%
name = {
    'Unnamed: 1': 'rank',
    'Unnamed: 2': 'University_name',
    'Unnamed: 3': 'cod'
}
df.rename(columns=name, inplace=True)
df
# Out:
#          rank                                    University_name  cod
# 0     1 (335)                  Lomonosov Moscow State University  RUS
# 1     2 (498)                  Saint Petersburg State University  RUS
# 2     3 (510)                     State University of Management  RUS
# 3     4 (553)      State University - Higher School of Economics  RUS
# 4     5 (560)  Peter the Great St Petersburg Polytechnic Univ...  RUS
# ..        ...                                                ...  ...
# 160  96 (786)                            Tambov State University  RUS
# 161  96 (786)                          Dagestan State University  RUS
# 162  97 (789)                         Yaroslavl State University  RUS
# 163  98 (790)               Kabardino-Balkarian State University  RUS
# 164  99 (802)                              Tver State University  RUS
#
# [165 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 0 to 164
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             165 non-null    object
#  1   University_name  165 non-null    object
#  2   cod              165 non-null    object
# dtypes: object(3)
# memory usage: 9.2+ KB

# %% [markdown]
# # Endi bo'lsa men taxsil olayotgan unversitetni jadvaldan izlab ko'ramiz

# %%
df.sort_values('University_name')
# Out:
#          rank                                    University_name  cod
# 36   35 (707)                             Altai State University  RUS
# 150  87 (768)                              Amur State University  RUS
# 120  76 (755)                   Bashkir State Medical University  RUS
# 107  71 (750)                           Bashkir State University  RUS
# 29   30 (697)           Bauman Moscow State Technical University  RUS
# ..        ...                                                ...  ...
# 134  80 (759)  Voronezh State University of Engineering Techn...  RUS
# 40   38 (710)                            Vyatka State University  RUS
# 105  70 (749)                     Yandex School of Data Analysis  RUS
# 162  97 (789)                         Yaroslavl State University  RUS
# 148  86 (767)  Yuri Gagarin State Technical University of Sar...  RUS
#
# [165 rows x 3 columns]

# %%
sub = 'Novosibirsk State University of Economics and Management'
df.University_name.str.find(sub)
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 160   -1
# 161   -1
# 162   -1
# 163   -1
# 164   -1
# Name: University_name, Length: 165, dtype: int64

# %%
df.iloc[0]
# Out:
# rank                                         1 (335)
# University_name    Lomonosov Moscow State University
# cod                                              RUS
# Name: 0, dtype: object

# %%
df[df.University_name == 'Novosibirsk State University of Economics and Management']
# Out:
# Empty DataFrame
# Columns: [rank, University_name, cod]
# Index: []

# %%
df.head(50)
# Out:
#         rank                                    University_name  cod
# 0    1 (335)                  Lomonosov Moscow State University  RUS
# 1    2 (498)                  Saint Petersburg State University  RUS
# 2    3 (510)                     State University of Management  RUS
# 3    4 (553)      State University - Higher School of Economics  RUS
# 4    5 (560)  Peter the Great St Petersburg Polytechnic Univ...  RUS
# 5    6 (573)                       Novosibirsk State University  RUS
# 6    7 (581)               Moscow Engineering Physics Institute  RUS
# 7    8 (589)       Skolkovo Institute of Science and Technology  RUS
# 8    9 (593)                             Tomsk State University  RUS
# 9   10 (605)                           Kazan Federal University  RUS
# 10  11 (612)         Moscow Institute of Physics and Technology  RUS
# 11  12 (621)                            Ural Federal University  RUS
# 12  13 (623)                                    ITMO University  RUS
# ...

# %% [markdown]
# Mana men o'qiydigan universitetni ham topdik

# %%
df[df.University_name == 'Novosibirsk State University']
# Out:
#       rank               University_name  cod
# 5  6 (573)  Novosibirsk State University  RUS

# %% [markdown]
# Va endi bu failni saqlab qo'yamiz

# %%
df.to_csv("Russian_Unversity_ranking.csv")

# %% [markdown]
# Thank you for read my file
