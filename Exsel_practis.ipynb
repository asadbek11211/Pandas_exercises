# %% [markdown]
# <a href="https://colab.research.google.com/github/asadbek11211/Pandas_exsamples/blob/main/Exsel_practis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 43 (delta 43), pack-reused 93
# Receiving objects: 100% (145/145), 9.72 MiB | 18.92 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
data = pd.read_excel("Ro'ziboyeva Dilnura Adabiyot_Savollar.xlsx", index_col="N")

# %%
#df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
#df.rename(columns={"A": "a", "B": "c"})
df = pd.DataFrame(data)
df.rename(columns={'OT EGASI':'Data'})
#df.rename(index={0: "x", 1: "y", 2: "z"})
df
# Out:
# a                                         OT    EGASI
# N
# 1                  Inodning nechta  hikoyasi bor edi?
# 2                 Inodning birinchi boyligi nima edi?
# 3                Inodning otasi qanday halok bo’lgan?
# 4                        Uning ikkinchi boyligi nima?
# 5                     Inodning uchinchi boyligi nima?
# 6            Inodning oti nima uchun unga qadrli edi?
# 7                 Inodning oilasi qanday vafot etgan?
# 8   Qorabayir ot nechchi yildan buyon ko’pkarilard...
# 9     Maktabda necha yoshli bolalar ta’lim olishardi?
# 10  Inod bo’sh paytlarda bolalar bilan qanday mash...
# 11                         Chorbog’ qorovuli kim edi?
# 12  Inod shaxsiy ot saqlash man qilinganini kimdan...
# 13             Biya sotib olish kimning vazifasi edi?
# 14            Egamberdining pinhoniy niyati nima edi?
# 15  Egamberdi qaysi  cho’ponning baytali turgan ho...
# 16  ”Ko’pga kelgan to’y “maqoli qaysi asarda uchra...
# ...

# %%
df.sort_index(ascending=False)
# Out:
# a                                         OT    EGASI
# N
# 27  Yozuvchi otni tasvirlar ekan “oddiygina” so’zi...
# 26  Asardagi chiroyli gaplardan,kitobiy so’zlardan...
# 25  Birovlarning mulk-u molini o’zlashtirishdan qa...
# 24                  ”Inod “ so’zining ma’nosi qanday?
# 23  ”Inod bir necha oydan so’ng  Egamberdining niy...
# 22  ”Meni qamashadimi”-deb o’yladi Inod. Inod nega...
# 21  Inod ikkinchi marta otning o’rniga nima taklif...
# 20    Egamberdi Inoddan sigirni qayerda olmoqchi edi?
# 19       Inod Egamberdiga otning evaziga nima beradi?
# 18  ”Sizlarga ot suv biln havoday zarur” deb kim a...
# 17    Egamberdi Inodga nima sababdan senlab gapiradi?
# 16  ”Ko’pga kelgan to’y “maqoli qaysi asarda uchra...
# 15  Egamberdi qaysi  cho’ponning baytali turgan ho...
# 14            Egamberdining pinhoniy niyati nima edi?
# 13             Biya sotib olish kimning vazifasi edi?
# 12  Inod shaxsiy ot saqlash man qilinganini kimdan...
# ...

# %%
df.head()
# Out:
# a                           OT    EGASI
# N
# 1    Inodning nechta  hikoyasi bor edi?
# 2   Inodning birinchi boyligi nima edi?
# 3  Inodning otasi qanday halok bo’lgan?
# 4          Uning ikkinchi boyligi nima?
# 5       Inodning uchinchi boyligi nima?

# %%
df.sort_index(axis=1)
# Out:
# a                                         OT    EGASI
# N
# 1                  Inodning nechta  hikoyasi bor edi?
# 2                 Inodning birinchi boyligi nima edi?
# 3                Inodning otasi qanday halok bo’lgan?
# 4                        Uning ikkinchi boyligi nima?
# 5                     Inodning uchinchi boyligi nima?
# 6            Inodning oti nima uchun unga qadrli edi?
# 7                 Inodning oilasi qanday vafot etgan?
# 8   Qorabayir ot nechchi yildan buyon ko’pkarilard...
# 9     Maktabda necha yoshli bolalar ta’lim olishardi?
# 10  Inod bo’sh paytlarda bolalar bilan qanday mash...
# 11                         Chorbog’ qorovuli kim edi?
# 12  Inod shaxsiy ot saqlash man qilinganini kimdan...
# 13             Biya sotib olish kimning vazifasi edi?
# 14            Egamberdining pinhoniy niyati nima edi?
# 15  Egamberdi qaysi  cho’ponning baytali turgan ho...
# 16  ”Ko’pga kelgan to’y “maqoli qaysi asarda uchra...
# ...
